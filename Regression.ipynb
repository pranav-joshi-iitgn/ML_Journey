# %%
from numpy import *
from matplotlib.pyplot import *
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.datasets import load_diabetes
X,y = load_diabetes(return_X_y=True)
models = [GradientBoostingRegressor(),RandomForestRegressor(),LinearRegression()]
styles = ["gd","b^","ys"]
names = ["GradientBoostingRegressor","RandomForestRegressor","LinearRegression"]

# %%
for i in range(3):
    models[i].fit(X,y)
    print(names[i],":\n    ",sum((models[i].predict(X)-y)**2),"\n")
# Out:
# GradientBoostingRegressor :
#      526720.0854824018
#
# RandomForestRegressor :
#      205909.42079999996
#
# LinearRegression :
#      1263985.7856333435

# %%
X_test = X[:20]
y_test = y[:20]
for i in range(3):
    plot(models[i].predict(X_test),styles[i],label=names[i])
tick_params(axis="x",which="both",bottom=False,top=False,labelbottom=False)
ylabel("predicted")
xlabel("training samples")
legend()
show()
